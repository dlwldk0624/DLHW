# %% [markdown]
# <a href="https://colab.research.google.com/github/dlwldk0624/DLHW/blob/main/python_basics_homework01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📝 Python Basics Homework — 20 Practice Problems
#
# This homework combines everything you learned in class: **comments, input/output, variables, operators, functions, and modules**. Each problem asks you to reuse those ideas with new content, so you get more practice with the same core skills.
#
# Some problems (marked with 💡) use a tool you haven't formally learned yet (like `if` or `for`). Don't worry — a **hint with a working example** is provided right above those problems. Just adapt the example to the new situation.
#
# ---
#
# ## 📮 Submission Guidelines (by 10PM on 9/30)
#
# 1. Solve all 20 problems below, one code cell at a time.
# 2. When you're done, go to **Runtime → Run all** so that every cell shows its output (don't skip this — an empty notebook with no output will not be accepted).
# 3. Go to [github.com](https://github.com) and create a **new repository** named exactly **`DLHW`** (make it Public, so your instructor can open it).
# 4. Upload this completed notebook (with outputs visible) into your `DLHW` repository.
#    - Easiest way: in Colab, go to **File → Save a copy in GitHub**, choose your `DLHW` repository, and save.
#    - Or: **File → Download → Download .ipynb**, then upload that file into `DLHW` on github.com (**Add file → Upload files**).
# 5. Rename the file something clear, e.g. `week03_homework_yourname.ipynb`.
#
# > ⚠️ Make sure your outputs are saved in the file! If you clear outputs or upload a notebook that was never run, your instructor won't be able to see your results.

# %% [markdown]
# ---
# ## Section A — Warm-Up (Comments, Input/Output, Variables)

# %% [markdown]
# ### Problem 1: Comment It
#
# Below is a line of code. Add a comment **above** it explaining what it does, in your own words.

# %%
# TODO: add your comment above this line
print("Welcome to today's English lesson!")

# %% [markdown]
# ### Problem 2: Introduce Yourself
#
# Use `print()` to output three separate lines: your name, your major, and your favorite subject.

# %%
# TODO: write your code here
print("Jia Lee, English Education, and English")
# Out:
# Jia Lee, English Education, and English

# %% [markdown]
# ### Problem 3: Ask and Answer
#
# Use `input()` to ask the user "What is your favorite English word?" and store the answer in a variable called `fav_word`. Then print: `Your favorite word is: ___`

# %%
# TODO: write your code here
print("What is your favorite English word?")
fav_word = input("Your favorite word is:")
print("Your favorite word is:", fav_word)
# Out:
# What is your favorite English word?
# Your favorite word is:apple
# Your favorite word is: apple

# %% [markdown]
# ### Problem 4: Two Inputs, One Sentence
#
# Ask the user for an English word and its meaning (two separate `input()` calls). Then print a sentence combining both, like: `apple means 사과`

# %%
# TODO: write your code here
word = input("Enter an English word: ")
meaning = input("Enter its meaning: ")

print(word, "means", meaning)
# Out:
# Enter an English word: apple
# Enter its meaning: 사과
# apple means 사과

# %% [markdown]
# ### Problem 5: Vocabulary Card
#
# Create three variables: `word`, `part_of_speech` (e.g., "noun", "verb"), and `meaning`. Print them together using an f-string, like:
# `friend (noun): 친구`

# %%
# TODO: write your code here
word = "friend"
part_of_speech = "noun"
meaning = "친구"

print(f"{word}({part_of_speech}):{meaning}")
# Out:
# friend(noun):친구

# %% [markdown]
# ### Problem 6: Total Score
#
# Create two variables, `quiz1_score` and `quiz2_score`, with any numbers you like. Calculate and print their **sum**.

# %%
# TODO: write your code here
quiz1_score = 85
quiz2_score = 90

total_score = quiz1_score + quiz2_score

print(total_score)
# Out:
# 175

# %% [markdown]
# ### Problem 7: Average Score
#
# Using the same two quiz scores from Problem 6, calculate and print the **average** (sum divided by 2).

# %%
# TODO: write your code here
quiz1_score = 85
quiz2_score = 90

average = (quiz1_score + quiz2_score) / 2

print(average)
# Out:
# 87.5

# %% [markdown]
# ### Problem 8: Word Length Difference
#
# Create two variables, `word1` and `word2`, with different English words. Print the **difference in length** between them (use `len()` and subtraction). The result may be negative — that's okay for now!

# %%
# TODO: write your code here
word1 = "apple"
word2 = "banana"

difference = len(word1) - len(word2)

print(difference)
# Out:
# -1

# %% [markdown]
# ---
# ## Section B — Functions & Modules

# %% [markdown]
# ### Problem 9: Double It
#
# Write a function `double_score(score)` that returns the score multiplied by 2. Test it by calling it with a few different numbers.

# %%
# TODO: write your code here
def double_score(score):
    return score * 2

print(double_score(10))
print(double_score(25))
print(double_score(50))
# Out:
# 20
# 50
# 100

# %% [markdown]
# ### Problem 10: Percentage Function
#
# Write a function `to_percentage(correct, total)` that returns the percentage score (`correct / total * 100`). Test it with at least two different pairs of numbers.

# %%
# TODO: write your code here
def to_percentage(correct, total):
    return correct / total * 100

print(to_percentage(8, 10))
print(to_percentage(15, 20))
# Out:
# 80.0
# 75.0

# %% [markdown]
# ### Problem 11: Longer Word Function
#
# Write a function `is_longer(word1, word2)` that returns `True` if `word1` is longer than `word2`, otherwise `False`. (Hint: compare `len(word1)` and `len(word2)` using `>`.) Test it with two pairs of words.

# %%
# TODO: write your code here
def is_longer(word1, word2):
    return len(word1) > len(word2)

print(is_longer("apple", "cat"))       # True
print(is_longer("book", "teacher"))    # False
# Out:
# True
# False

# %% [markdown]
# ### Problem 12: Random Greeting
#
# Import the `random` module. Create a list of three greetings, e.g. `["Hello!", "Hi there!", "Good morning!"]`. Use `random.choice()` to print one randomly chosen greeting.

# %%
# TODO: write your code here
import random

greetings = ["Hello!", "Hi there!", "Good morning!"]

print(random.choice(greetings))
# Out:
# Hello!

# %% [markdown]
# ### Problem 13: Random Number Practice
#
# Import `random`. Use `random.randint()` to generate a random number between 1 and 100, and store it in a variable called `mystery_number`. Print it.

# %%
# TODO: write your code here
import random

mystery_number = random.randint(1, 100)

print(mystery_number)
# Out:
# 6

# %% [markdown]
# ### Problem 14: Flashcard Maker Function
#
# Write a function `make_flashcard(word, meaning)` that **returns** a string like `"word -> meaning"`. Call the function with two different words and print the results.

# %%
# TODO: write your code here
def make_flashcard(word, meaning):
    return word + " -> " + meaning

print(make_flashcard("apple", "a kind of fruit"))
print(make_flashcard("teacher", "a person who teaches students"))
# Out:
# apple -> a kind of fruit
# teacher -> a person who teaches students

# %% [markdown]
# ---
# ## Section C — Combining Everything
#
# These problems combine multiple ideas. A few use tools you haven't formally learned (`if`, `for`, lists) — hints and examples are provided.

# %% [markdown]
# ### Problem 15: Pass or Fail (using if)
#
# Ask the user for `correct` and `total` (as numbers, using `int(input(...))`). Calculate the `percentage`. Then print `"Pass"` if the percentage is 60 or higher, otherwise print `"Fail"`.

# %% [markdown]
# 💡 **Hint — `if` / `else` example** (you haven't learned this yet, but here's how it works):
# ```python
# temperature = 75
#
# if temperature > 80:
#     print("It's hot!")
# else:
#     print("It's not that hot.")
# ```
# `if` checks a condition (something that is `True` or `False`, just like the comparison operators you learned). If it's `True`, the indented code under `if` runs. Otherwise, the code under `else` runs.

# %%
# TODO: write your code here
correct = int(input("Enter the number of correct answers: "))
total = int(input("Enter the total number of questions: "))

percentage = correct / total * 100

if percentage >= 60:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter the number of correct answers: 90
# Enter the total number of questions: 100
# Pass

# %% [markdown]
# ### Problem 16: Grade Message Function
#
# Write a function `pass_or_fail(percentage)` that returns `"Pass"` if `percentage >= 60`, otherwise returns `"Fail"`. (This combines Problem 15's `if` logic with what you learned about functions.) Test it with a few different percentages.

# %%
# TODO: write your code here
def pass_or_fail(percentage):
    if percentage >= 60:
        return "Pass"
    else:
        return "Fail"

print(pass_or_fail(85))  # Pass
print(pass_or_fail(60))  # Pass
print(pass_or_fail(45))  # Fail
# Out:
# Pass
# Pass
# Fail

# %% [markdown]
# ### Problem 17: Repeat With a Loop (using for)
#
# Create a list of 3 English words. Using a `for` loop, print each word along with its length, like: `apple - 5 letters`

# %% [markdown]
# 💡 **Hint — `for` loop example** (you haven't learned this yet):
# ```python
# colors = ["red", "blue", "green"]
#
# for color in colors:
#     print(color, "has", len(color), "letters")
# ```
# The `for` loop takes each item in the list, one at a time, and runs the indented code with that item.

# %%
# TODO: write your code here
words = ["apple", "teacher", "school"]

for word in words:
    print(word, "-", len(word), "letters")
# Out:
# apple - 5 letters
# teacher - 7 letters
# school - 6 letters

# %% [markdown]
# ### Problem 18: Random Word Picker + Function
#
# Create a list of 5 English words. Write a function `pick_random_word(word_list)` that uses `random.choice()` to return one random word from the list. Call the function and print the result.

# %%
# TODO: write your code here
import random

words = ["apple", "banana", "teacher", "school", "computer"]

def pick_random_word(word_list):
    return random.choice(word_list)

print(pick_random_word(words))
# Out:
# school

# %% [markdown]
# ### Problem 19: Mini Vocabulary Quiz (one question)
#
# Create two variables: `question_word` (e.g. `"apple"`) and `correct_meaning` (e.g. `"사과"`). Ask the user to type the meaning using `input()`. Write a function `check_answer(user_answer, correct_answer)` that returns `True` or `False` (ignore uppercase/lowercase and extra spaces using `.strip().lower()`). Print `"Correct!"` if the function returns `True`, otherwise print `"Try again!"`.

# %% [markdown]
# 💡 **Hint — combining a function with `if`:**
# ```python
# def is_even(number):
#     return number % 2 == 0
#
# n = 4
# if is_even(n):
#     print("Even!")
# else:
#     print("Odd!")
# ```

# %%
# TODO: write your code here
question_word = "apple"
correct_meaning = "사과"

user_answer = input("What is the meaning of " + question_word + "? ")

def check_answer(user_answer, correct_answer):
    return user_answer.strip().lower() == correct_answer.strip().lower()

if check_answer(user_answer, correct_meaning):
    print("Correct!")
else:
    print("Try again!")
# Out:
# What is the meaning of apple? 불
# Try again!

# %% [markdown]
# ### Problem 20: Capstone: 3-Question Vocabulary Quiz
#
# This is the big one! Combine everything:
# 1. Create two lists: `word_list` (5 English words) and `meaning_list` (their Korean meanings, in the same order).
# 2. Write the `check_answer(user_answer, correct_answer)` function from Problem 19.
# 3. Using a `for` loop that runs 3 times, use `random.randint()` to pick a random index each time, ask the user for the meaning of that word, and use `check_answer()` to check it.
# 4. Keep track of how many the user got right in a variable called `score`.
# 5. After the loop, print the final score, like: `Final score: 2/3`

# %% [markdown]
# 💡 This combines ideas from Problems 17, 18, and 19. Here's a skeleton to help you get started — fill in the blanks:
# ```python
# import random
#
# word_list = ["apple", "book", "friend", "school", "happy"]
# meaning_list = ["사과", "책", "친구", "학교", "행복한"]
#
# def check_answer(user_answer, correct_answer):
#     return user_answer.strip().lower() == correct_answer.strip().lower()
#
# score = 0
# total_questions = 3
#
# for i in range(total_questions):
#     index = random.randint(0, len(word_list) - 1)
#     # TODO: get the word and meaning at that index
#     # TODO: ask the user for the meaning
#     # TODO: use check_answer() and update score if correct
#     pass
#
# print(f"Final score: {score}/{total_questions}")
# ```

# %%
# TODO: write your code here
import random

word_list = ["apple", "school", "teacher", "computer", "book"]
meaning_list = ["사과", "학교", "선생님", "컴퓨터", "책"]

def check_answer(user_answer, correct_answer):
    return user_answer.strip().lower() == correct_answer.strip().lower()

score = 0

for i in range(3):
    random_index = random.randint(0, len(word_list) - 1)

    question_word = word_list[random_index]
    correct_meaning = meaning_list[random_index]

    user_answer = input("What is the meaning of " + question_word + "? ")

    if check_answer(user_answer, correct_meaning):
        print("Correct!")
        score = score + 1
    else:
        print("Try again!")

print("Final score:", str(score) + "/3")
# Out:
# What is the meaning of book? 책
# Correct!
# What is the meaning of teacher? 선생님
# Correct!
# What is the meaning of apple? 사과
# Correct!
# Final score: 3/3

# %% [markdown]
# ---
# ## 🎉 You're Done!
#
# Don't forget the submission steps at the top of this notebook:
# 1. Run all cells so your outputs are saved.
# 2. Create a GitHub repository named **`DLHW`**.
# 3. Upload this notebook (with outputs) to that repository.
#
# Great job combining everything you've learned! 🚀
